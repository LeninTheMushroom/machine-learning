# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
import pandas as pd
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('C:\Users\Admin\Desktop\mlbootcamp5_train.csv', sep=';', index_col='id')

# %%
df.head()
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0   18393       2     168    62.0    110     80            1     1      0
# 1   20228       1     156    85.0    140     90            3     1      0
# 2   18857       1     165    64.0    130     70            3     1      0
# 3   17623       2     169    82.0    150    100            1     1      0
# 4   17474       1     156    56.0    100     60            1     1      0
#
#     alco  active  cardio
# id
# 0      0       1       0
# 1      0       1       1
# 2      0       0       1
# 3      0       1       1
# 4      0       0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 12 columns):
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(11)
# memory usage: 6.9 MB

# %% [markdown]
# # 1 - height & smoke

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # 3 - ap_hi & ap_lo

# %%
sns.heatmap(df.corr(method='spearman'))

# %% [markdown]
# # 4 - аж 7 штук

# %%
sns_plot = sns.jointplot(df['ap_hi'], df['ap_lo'])

# %%
#df = df[(df['ap_lo']>0) & (df['ap_hi']>0) &(df['ap_hi']>=df['ap_lo'])]
df = df[(df['ap_lo']!=0)&(df['ap_hi']!=0)]
ser1 = pd.Series([np.log(x) for x in df['ap_lo']])
ser2 = pd.Series([np.log(x) for x in df['ap_hi']])
sns_plot = sns.jointplot(ser1, ser2)

# %% [markdown]
# # 5 - 53

# %%
df['age_years'] = (df['age']/365.0).astype(int)
ax = sns.countplot(x="age_years", hue="cardio", data=df)
